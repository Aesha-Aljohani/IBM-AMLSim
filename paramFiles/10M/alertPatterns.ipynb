# %%
alertPatterns.csv

# %% [markdown]
# # alertPatterns

# %% [markdown]
# ## Imports Libraries

# %%
#1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('alertPatterns.csv')

# %%
df.head()
# Out:
#    count     type  schedule_id  min_accounts  max_accounts  min_amount  \
# 0  30000   fan_in            2             5            10       100.0
# 1  30000  fan_out            2             5            10       100.0
# 2  40000    cycle            2             5            10       100.0
#
#    max_amount  min_period  max_period bank_id  is_sar
# 0       200.0           5          20    bank    True
# 1       200.0           5          20    bank    True
# 2       200.0           5          20    bank    True

# %%
df.shape
# Out:
# (3, 11)

# %%
df.columns
# Out:
# Index(['count', 'type', 'schedule_id', 'min_accounts', 'max_accounts',
#        'min_amount', 'max_amount', 'min_period', 'max_period', 'bank_id',
#        'is_sar'],
#       dtype='object')

# %%
df.dtypes
# Out:
# count             int64
# type             object
# schedule_id       int64
# min_accounts      int64
# max_accounts      int64
# min_amount      float64
# max_amount      float64
# min_period        int64
# max_period        int64
# bank_id          object
# is_sar             bool
# dtype: object

# %%
df.describe()
# Out:
#               count  schedule_id  min_accounts  max_accounts  min_amount  \
# count      3.000000          3.0           3.0           3.0         3.0
# mean   33333.333333          2.0           5.0          10.0       100.0
# std     5773.502692          0.0           0.0           0.0         0.0
# min    30000.000000          2.0           5.0          10.0       100.0
# 25%    30000.000000          2.0           5.0          10.0       100.0
# 50%    30000.000000          2.0           5.0          10.0       100.0
# 75%    35000.000000          2.0           5.0          10.0       100.0
# max    40000.000000          2.0           5.0          10.0       100.0
#
#        max_amount  min_period  max_period
# count         3.0         3.0         3.0
# mean        200.0         5.0        20.0
# std           0.0         0.0         0.0
# min         200.0         5.0        20.0
# 25%         200.0         5.0        20.0
# 50%         200.0         5.0        20.0
# 75%         200.0         5.0        20.0
# max         200.0         5.0        20.0

# %%
df.describe(include = 'all').T
# Out:
#              count unique    top freq     mean     std    min    25%    50%  \
# count            3    NaN    NaN  NaN  33333.3  5773.5  30000  30000  30000
# type             3      3  cycle    1      NaN     NaN    NaN    NaN    NaN
# schedule_id      3    NaN    NaN  NaN        2       0      2      2      2
# min_accounts     3    NaN    NaN  NaN        5       0      5      5      5
# max_accounts     3    NaN    NaN  NaN       10       0     10     10     10
# min_amount       3    NaN    NaN  NaN      100       0    100    100    100
# max_amount       3    NaN    NaN  NaN      200       0    200    200    200
# min_period       3    NaN    NaN  NaN        5       0      5      5      5
# max_period       3    NaN    NaN  NaN       20       0     20     20     20
# bank_id          3      1   bank    3      NaN     NaN    NaN    NaN    NaN
# is_sar           3      1   True    3      NaN     NaN    NaN    NaN    NaN
#
#                 75%    max
# count         35000  40000
# type            NaN    NaN
# schedule_id       2      2
# min_accounts      5      5
# max_accounts     10     10
# min_amount      100    100
# max_amount      200    200
# min_period        5      5
# max_period       20     20
# bank_id         NaN    NaN
# is_sar          NaN    NaN

# %% [markdown]
# ## the end
