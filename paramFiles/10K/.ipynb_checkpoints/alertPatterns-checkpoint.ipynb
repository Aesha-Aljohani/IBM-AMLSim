# %% [markdown]
# # alertPatterns

# %% [markdown]
# ## import

# %%
#1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#2

# %%
alertPatterns = pd.read_csv('alertPatterns.csv')

# %%
alertPatterns.head()
# Out:
#    count     type  schedule_id  min_accounts  max_accounts  min_amount  \
# 0     30   fan_in            2             5            10       100.0
# 1     30  fan_out            2             5            10       100.0
# 2     40    cycle            2             5            10       100.0
#
#    max_amount  min_period  max_period bank_id  is_sar
# 0       200.0           5          20    bank    True
# 1       200.0           5          20    bank    True
# 2       200.0           5          20    bank    True

# %%
alertPatterns.shape
# Out:
# (3, 11)

# %%
alertPatterns.columns
# Out:
# Index(['count', 'type', 'schedule_id', 'min_accounts', 'max_accounts',
#        'min_amount', 'max_amount', 'min_period', 'max_period', 'bank_id',
#        'is_sar'],
#       dtype='object')

# %%
alertPatterns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   count         3 non-null      int64
#  1   type          3 non-null      object
#  2   schedule_id   3 non-null      int64
#  3   min_accounts  3 non-null      int64
#  4   max_accounts  3 non-null      int64
#  5   min_amount    3 non-null      float64
#  6   max_amount    3 non-null      float64
#  7   min_period    3 non-null      int64
#  8   max_period    3 non-null      int64
#  9   bank_id       3 non-null      object
#  10  is_sar        3 non-null      bool
# dtypes: bool(1), float64(2), int64(6), object(2)
# memory usage: 371.0+ bytes

# %%
alertPatterns.describe()
# Out:
#            count  schedule_id  min_accounts  max_accounts  min_amount  \
# count   3.000000          3.0           3.0           3.0         3.0
# mean   33.333333          2.0           5.0          10.0       100.0
# std     5.773503          0.0           0.0           0.0         0.0
# min    30.000000          2.0           5.0          10.0       100.0
# 25%    30.000000          2.0           5.0          10.0       100.0
# 50%    30.000000          2.0           5.0          10.0       100.0
# 75%    35.000000          2.0           5.0          10.0       100.0
# max    40.000000          2.0           5.0          10.0       100.0
#
#        max_amount  min_period  max_period
# count         3.0         3.0         3.0
# mean        200.0         5.0        20.0
# std           0.0         0.0         0.0
# min         200.0         5.0        20.0
# 25%         200.0         5.0        20.0
# 50%         200.0         5.0        20.0
# ...

# %%
alertPatterns.describe(include = 'all').T
# Out:
#              count unique    top freq     mean     std  min  25%  50%  75%  \
# count            3    NaN    NaN  NaN  33.3333  5.7735   30   30   30   35
# type             3      3  cycle    1      NaN     NaN  NaN  NaN  NaN  NaN
# schedule_id      3    NaN    NaN  NaN        2       0    2    2    2    2
# min_accounts     3    NaN    NaN  NaN        5       0    5    5    5    5
# max_accounts     3    NaN    NaN  NaN       10       0   10   10   10   10
# min_amount       3    NaN    NaN  NaN      100       0  100  100  100  100
# max_amount       3    NaN    NaN  NaN      200       0  200  200  200  200
# min_period       3    NaN    NaN  NaN        5       0    5    5    5    5
# max_period       3    NaN    NaN  NaN       20       0   20   20   20   20
# bank_id          3      1   bank    3      NaN     NaN  NaN  NaN  NaN  NaN
# is_sar           3      1   True    3      NaN     NaN  NaN  NaN  NaN  NaN
#
#               max
# count          40
# type          NaN
# ...

# %%
alertPatterns.isnull().sum()#Finding missing data
# Out:
# count           0
# type            0
# schedule_id     0
# min_accounts    0
# max_accounts    0
# min_amount      0
# max_amount      0
# min_period      0
# max_period      0
# bank_id         0
# is_sar          0
# dtype: int64

# %%
# The number of duplicates 
alertPatterns.duplicated(subset=None, keep='first').sum()
# Out:
# 0

# %% [markdown]
# ## the end
