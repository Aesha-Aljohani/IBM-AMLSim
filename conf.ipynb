# %% [markdown]
# # conf

# %% [markdown]
# ## import Library

# %%
#1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Read Data

# %%
df = pd.read_json('conf.json')

# %%
df.head(20)
# Out:
#                       general  \
# random_seed                 0
# simulation_name        sample
# total_steps               720
# base_date          2017-01-01
# min_amount                NaN
# max_amount                NaN
# min_balance               NaN
# max_balance               NaN
# start_step                NaN
# end_step                  NaN
# start_range               NaN
# end_range                 NaN
# transaction_model         NaN
# margin_ratio              NaN
# bank_id                   NaN
# cash_in                   NaN
# cash_out                  NaN
# directory                 NaN
# schema                    NaN
# accounts                  NaN
#
#                                                              default  \
# random_seed                                                      NaN
# simulation_name                                                  NaN
# total_steps                                                      NaN
# base_date                                                        NaN
# min_amount                                                       100
# max_amount                                                      1000
# min_balance                                                    50000
# max_balance                                                   100000
# start_step                                                        -1
# end_step                                                          -1
# start_range                                                       -1
# end_range                                                         -1
# transaction_model                                                  1
# margin_ratio                                                     0.1
# bank_id                                                      default
# cash_in            {'normal_interval': 100, 'fraud_interval': 50,...
# cash_out           {'normal_interval': 10, 'fraud_interval': 100,...
# directory                                                        NaN
# schema                                                           NaN
# accounts                                                         NaN
#
#                            input      temporal        output graph_generator  \
# random_seed                  NaN           NaN           NaN             NaN
# simulation_name              NaN           NaN           NaN             NaN
# total_steps                  NaN           NaN           NaN             NaN
# base_date                    NaN           NaN           NaN             NaN
# min_amount                   NaN           NaN           NaN             NaN
# max_amount                   NaN           NaN           NaN             NaN
# min_balance                  NaN           NaN           NaN             NaN
# max_balance                  NaN           NaN           NaN             NaN
# start_step                   NaN           NaN           NaN             NaN
# end_step                     NaN           NaN           NaN             NaN
# start_range                  NaN           NaN           NaN             NaN
# end_range                    NaN           NaN           NaN             NaN
# transaction_model            NaN           NaN           NaN             NaN
# margin_ratio                 NaN           NaN           NaN             NaN
# bank_id                      NaN           NaN           NaN             NaN
# cash_in                      NaN           NaN           NaN             NaN
# cash_out                     NaN           NaN           NaN             NaN
# directory          paramFiles/1K           tmp       outputs             NaN
# schema               schema.json           NaN           NaN             NaN
# accounts            accounts.csv  accounts.csv  accounts.csv             NaN
#
#                    simulator visualizer
# random_seed              NaN        NaN
# simulation_name          NaN        NaN
# total_steps              NaN        NaN
# base_date                NaN        NaN
# min_amount               NaN        NaN
# max_amount               NaN        NaN
# min_balance              NaN        NaN
# max_balance              NaN        NaN
# start_step               NaN        NaN
# end_step                 NaN        NaN
# start_range              NaN        NaN
# end_range                NaN        NaN
# transaction_model        NaN        NaN
# margin_ratio             NaN        NaN
# bank_id                  NaN        NaN
# cash_in                  NaN        NaN
# cash_out                 NaN        NaN
# directory                NaN        NaN
# schema                   NaN        NaN
# accounts                 NaN        NaN

# %%
df.tail(30)
# Out:
#                        general default                input  \
# alert_patterns             NaN     NaN    alertPatterns.csv
# degree                     NaN     NaN           degree.csv
# transaction_type           NaN     NaN  transactionType.csv
# is_aggregated_accounts     NaN     NaN                 True
# transactions               NaN     NaN                  NaN
# alert_members              NaN     NaN                  NaN
# cash_transactions          NaN     NaN                  NaN
# alert_transactions         NaN     NaN                  NaN
# sar_accounts               NaN     NaN                  NaN
# party_individuals          NaN     NaN                  NaN
# party_organizations        NaN     NaN                  NaN
# account_mapping            NaN     NaN                  NaN
# resolved_entities          NaN     NaN                  NaN
# transaction_log            NaN     NaN                  NaN
# counter_log                NaN     NaN                  NaN
# diameter_log               NaN     NaN                  NaN
# degree_threshold           NaN     NaN                  NaN
# high_risk_countries        NaN     NaN                  NaN
# high_risk_business         NaN     NaN                  NaN
# compute_diameter           NaN     NaN                  NaN
# transaction_limit          NaN     NaN                  NaN
# transaction_interval       NaN     NaN                  NaN
# sar_interval               NaN     NaN                  NaN
# sar_balance_ratio          NaN     NaN                  NaN
# numBranches                NaN     NaN                  NaN
# wcc                        NaN     NaN                  NaN
# alert                      NaN     NaN                  NaN
# count                      NaN     NaN                  NaN
# clustering                 NaN     NaN                  NaN
# diameter                   NaN     NaN                  NaN
#
#                                  temporal                      output  \
# alert_patterns                        NaN                         NaN
# degree                                NaN                         NaN
# transaction_type                      NaN                         NaN
# is_aggregated_accounts                NaN                         NaN
# transactions             transactions.csv            transactions.csv
# alert_members           alert_members.csv          alert_accounts.csv
# cash_transactions                     NaN                 cash_tx.csv
# alert_transactions                    NaN      alert_transactions.csv
# sar_accounts                          NaN            sar_accounts.csv
# party_individuals                     NaN    individuals-bulkload.csv
# party_organizations                   NaN  organizations-bulkload.csv
# account_mapping                       NaN          accountMapping.csv
# resolved_entities                     NaN        resolvedentities.csv
# transaction_log                       NaN                  tx_log.csv
# counter_log                           NaN                tx_count.csv
# diameter_log                          NaN                diameter.csv
# degree_threshold                      NaN                         NaN
# high_risk_countries                   NaN                         NaN
# high_risk_business                    NaN                         NaN
# compute_diameter                      NaN                         NaN
# transaction_limit                     NaN                         NaN
# transaction_interval                  NaN                         NaN
# sar_interval                          NaN                         NaN
# sar_balance_ratio                     NaN                         NaN
# numBranches                           NaN                         NaN
# wcc                                   NaN                         NaN
# alert                                 NaN                         NaN
# count                                 NaN                         NaN
# clustering                            NaN                         NaN
# diameter                              NaN                         NaN
#
#                        graph_generator  simulator    visualizer
# alert_patterns                     NaN        NaN           NaN
# degree                             NaN        NaN       deg.png
# transaction_type                   NaN        NaN           NaN
# is_aggregated_accounts             NaN        NaN           NaN
# transactions                       NaN        NaN           NaN
# alert_members                      NaN        NaN           NaN
# cash_transactions                  NaN        NaN           NaN
# alert_transactions                 NaN        NaN           NaN
# sar_accounts                       NaN        NaN           NaN
# party_individuals                  NaN        NaN           NaN
# party_organizations                NaN        NaN           NaN
# account_mapping                    NaN        NaN           NaN
# resolved_entities                  NaN        NaN           NaN
# transaction_log                    NaN        NaN           NaN
# counter_log                        NaN        NaN           NaN
# diameter_log                       NaN        NaN           NaN
# degree_threshold                    10        NaN           NaN
# high_risk_countries                           NaN           NaN
# high_risk_business                            NaN           NaN
# compute_diameter                   NaN        0.0           NaN
# transaction_limit                  NaN        0.0           NaN
# transaction_interval               NaN        7.0           NaN
# sar_interval                       NaN        7.0           NaN
# sar_balance_ratio                  NaN        1.0           NaN
# numBranches                        NaN     1000.0           NaN
# wcc                                NaN        NaN       wcc.png
# alert                              NaN        NaN     alert.png
# count                              NaN        NaN     count.png
# clustering                         NaN        NaN        cc.png
# diameter                           NaN        NaN  diameter.png

# %%
df.shape
# Out:
# (50, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, random_seed to diameter
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   general          4 non-null      object
#  1   default          13 non-null     object
#  2   input            7 non-null      object
#  3   temporal         4 non-null      object
#  4   output           14 non-null     object
#  5   graph_generator  3 non-null      object
#  6   simulator        6 non-null      float64
#  7   visualizer       6 non-null      object
# dtypes: float64(1), object(7)
# memory usage: 3.5+ KB

# %%
df.describe()
# Out:
#          simulator
# count     6.000000
# mean    169.166667
# std     407.036812
# min       0.000000
# 25%       0.250000
# 50%       4.000000
# 75%       7.000000
# max    1000.000000

# %%
df.describe(include = 'all').T
# Out:
#                 count unique                       top freq     mean      std  \
# general             4      4                2017-01-01    1      NaN      NaN
# default            13     10                        -1    4      NaN      NaN
# input               7      7              accounts.csv    1      NaN      NaN
# temporal            4      4         alert_members.csv    1      NaN      NaN
# output             14     14  individuals-bulkload.csv    1      NaN      NaN
# graph_generator     3      2                              2      NaN      NaN
# simulator           6    NaN                       NaN  NaN  169.167  407.037
# visualizer          6      6              diameter.png    1      NaN      NaN
#
#                  min   25%  50%  75%   max
# general          NaN   NaN  NaN  NaN   NaN
# default          NaN   NaN  NaN  NaN   NaN
# input            NaN   NaN  NaN  NaN   NaN
# temporal         NaN   NaN  NaN  NaN   NaN
# output           NaN   NaN  NaN  NaN   NaN
# graph_generator  NaN   NaN  NaN  NaN   NaN
# simulator          0  0.25    4    7  1000
# visualizer       NaN   NaN  NaN  NaN   NaN

# %%
df.columns
# Out:
# Index(['general', 'default', 'input', 'temporal', 'output', 'graph_generator',
#        'simulator', 'visualizer'],
#       dtype='object')

# %%
df.dtypes
# Out:
# general             object
# default             object
# input               object
# temporal            object
# output              object
# graph_generator     object
# simulator          float64
# visualizer          object
# dtype: object

# %%
df.hist(figsize=(20,14))
plt.show()

# %% [markdown]
# ## the end
